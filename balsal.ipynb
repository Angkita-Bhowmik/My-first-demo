# %% [markdown]
# <a href="https://colab.research.google.com/github/Angkita-Bhowmik/My-first-demo/blob/main/balsal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

mylist= [1,2,3]

res= pd.Series(mylist)
del print
print(res)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
import numpy as np
arr= np.array([(1,2,3),(4,5,6)])
print("Array= \n",arr)
print(type(arr))
# Out:
# Array=
#  [[1 2 3]
#  [4 5 6]]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
xpts= np.array([1,2,3])
ypts= np.array([7,8,9])
plt.plot(xpts,ypts, marker='o',markerfacecolor='red', linestyle='dashed',linewidth=4, color='green')
plt.show()
